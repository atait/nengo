# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book](
# https://mitpress.mit.edu/books/neural-engineering) from MIT Press.
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="248526362" href="javascript:toggle_input_248526362()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_248526362;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_248526362 = document.getElementById("248526362");
#                 var cell = link_248526362;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_248526362;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_248526362 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_248526362 = cell.previousElementSibling;
#                 }
#                 input_248526362.style.display = "none"; // hide
#
#                 toggle_input_248526362 = function() {
#                     if (input_248526362.style.display == "none") {
#                         input_248526362.style.display = ""; // show
#                         link_248526362.innerHTML = "Hide Input";
#                     } else {
#                         input_248526362.style.display = "none"; // hide
#                         link_248526362.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_248526362 = $("a[id='248526362']");
#                 var cell_248526362 = link_248526362.parents("div.cell:first");
#                 if (cell_248526362.length == 0) {
#                     cell_248526362 = link_248526362.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_248526362 = cell_248526362.children("div.input");
#                 if (input_248526362.length == 0) {
#                     input_248526362 = cell_248526362.prev("div.nbinput");
#                 }
#                 input_248526362.hide();
#
#                 toggle_input_248526362 = function() {
#                     if (input_248526362.is(':hidden')) {
#                         input_248526362.slideDown();
#                         link_248526362[0].innerHTML = "Hide Input";
#                     } else {
#                         input_248526362.slideUp();
#                         link_248526362[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="556513448" href="javascript:toggle_input_556513448()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_556513448;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_556513448 = document.getElementById("556513448");
#                 var cell = link_556513448;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_556513448;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_556513448 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_556513448 = cell.previousElementSibling;
#                 }
#                 input_556513448.style.display = "none"; // hide
#
#                 toggle_input_556513448 = function() {
#                     if (input_556513448.style.display == "none") {
#                         input_556513448.style.display = ""; // show
#                         link_556513448.innerHTML = "Hide Input";
#                     } else {
#                         input_556513448.style.display = "none"; // hide
#                         link_556513448.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_556513448 = $("a[id='556513448']");
#                 var cell_556513448 = link_556513448.parents("div.cell:first");
#                 if (cell_556513448.length == 0) {
#                     cell_556513448 = link_556513448.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_556513448 = cell_556513448.children("div.input");
#                 if (input_556513448.length == 0) {
#                     input_556513448 = cell_556513448.prev("div.nbinput");
#                 }
#                 input_556513448.hide();
#
#                 toggle_input_556513448 = function() {
#                     if (input_556513448.is(':hidden')) {
#                         input_556513448.slideDown();
#                         link_556513448[0].innerHTML = "Hide Input";
#                     } else {
#                         input_556513448.slideUp();
#                         link_556513448[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders)

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)");
hide_input()
# Out:
#         <a id="1586905174" href="javascript:toggle_input_1586905174()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1586905174;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1586905174 = document.getElementById("1586905174");
#                 var cell = link_1586905174;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1586905174;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1586905174 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1586905174 = cell.previousElementSibling;
#                 }
#                 input_1586905174.style.display = "none"; // hide
#
#                 toggle_input_1586905174 = function() {
#                     if (input_1586905174.style.display == "none") {
#                         input_1586905174.style.display = ""; // show
#                         link_1586905174.innerHTML = "Hide Input";
#                     } else {
#                         input_1586905174.style.display = "none"; // hide
#                         link_1586905174.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1586905174 = $("a[id='1586905174']");
#                 var cell_1586905174 = link_1586905174.parents("div.cell:first");
#                 if (cell_1586905174.length == 0) {
#                     cell_1586905174 = link_1586905174.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1586905174 = cell_1586905174.children("div.input");
#                 if (input_1586905174.length == 0) {
#                     input_1586905174 = cell_1586905174.prev("div.nbinput");
#                 }
#                 input_1586905174.hide();
#
#                 toggle_input_1586905174 = function() {
#                     if (input_1586905174.is(':hidden')) {
#                         input_1586905174.slideDown();
#                         link_1586905174[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1586905174.slideUp();
#                         link_1586905174[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel('Neuron')
ax.set_xlabel('Time (s)');
hide_input()
# Out:
#         <a id="2074365420" href="javascript:toggle_input_2074365420()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2074365420;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2074365420 = document.getElementById("2074365420");
#                 var cell = link_2074365420;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2074365420;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2074365420 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2074365420 = cell.previousElementSibling;
#                 }
#                 input_2074365420.style.display = "none"; // hide
#
#                 toggle_input_2074365420 = function() {
#                     if (input_2074365420.style.display == "none") {
#                         input_2074365420.style.display = ""; // show
#                         link_2074365420.innerHTML = "Hide Input";
#                     } else {
#                         input_2074365420.style.display = "none"; // hide
#                         link_2074365420.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2074365420 = $("a[id='2074365420']");
#                 var cell_2074365420 = link_2074365420.parents("div.cell:first");
#                 if (cell_2074365420.length == 0) {
#                     cell_2074365420 = link_2074365420.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2074365420 = cell_2074365420.children("div.input");
#                 if (input_2074365420.length == 0) {
#                     input_2074365420 = cell_2074365420.prev("div.nbinput");
#                 }
#                 input_2074365420.hide();
#
#                 toggle_input_2074365420 = function() {
#                     if (input_2074365420.is(':hidden')) {
#                         input_2074365420.slideDown();
#                         link_2074365420[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2074365420.slideUp();
#                         link_2074365420[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(8, dimensions=1,
                       intercepts=intercepts,
                       max_rates=Uniform(80, 100),
                       encoders=encoders)
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale),
    np.arange(A.n_neurons))
hide_input()
# Out:
#         <a id="649878094" href="javascript:toggle_input_649878094()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_649878094;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_649878094 = document.getElementById("649878094");
#                 var cell = link_649878094;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_649878094;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_649878094 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_649878094 = cell.previousElementSibling;
#                 }
#                 input_649878094.style.display = "none"; // hide
#
#                 toggle_input_649878094 = function() {
#                     if (input_649878094.style.display == "none") {
#                         input_649878094.style.display = ""; // show
#                         link_649878094.innerHTML = "Hide Input";
#                     } else {
#                         input_649878094.style.display = "none"; // hide
#                         link_649878094.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_649878094 = $("a[id='649878094']");
#                 var cell_649878094 = link_649878094.parents("div.cell:first");
#                 if (cell_649878094.length == 0) {
#                     cell_649878094 = link_649878094.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_649878094 = cell_649878094.children("div.input");
#                 if (input_649878094.length == 0) {
#                     input_649878094 = cell_649878094.prev("div.nbinput");
#                 }
#                 input_649878094.hide();
#
#                 toggle_input_649878094 = function() {
#                     if (input_649878094.is(':hidden')) {
#                         input_649878094.slideDown();
#                         link_649878094[0].innerHTML = "Hide Input";
#                     } else {
#                         input_649878094.slideUp();
#                         link_649878094[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1509603962" href="javascript:toggle_input_1509603962()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1509603962;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1509603962 = document.getElementById("1509603962");
#                 var cell = link_1509603962;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1509603962;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1509603962 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1509603962 = cell.previousElementSibling;
#                 }
#                 input_1509603962.style.display = "none"; // hide
#
#                 toggle_input_1509603962 = function() {
#                     if (input_1509603962.style.display == "none") {
#                         input_1509603962.style.display = ""; // show
#                         link_1509603962.innerHTML = "Hide Input";
#                     } else {
#                         input_1509603962.style.display = "none"; // hide
#                         link_1509603962.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1509603962 = $("a[id='1509603962']");
#                 var cell_1509603962 = link_1509603962.parents("div.cell:first");
#                 if (cell_1509603962.length == 0) {
#                     cell_1509603962 = link_1509603962.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1509603962 = cell_1509603962.children("div.input");
#                 if (input_1509603962.length == 0) {
#                     input_1509603962 = cell_1509603962.prev("div.nbinput");
#                 }
#                 input_1509603962.hide();
#
#                 toggle_input_1509603962 = function() {
#                     if (input_1509603962.is(':hidden')) {
#                         input_1509603962.slideDown();
#                         link_1509603962[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1509603962.slideUp();
#                         link_1509603962[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="606694866" href="javascript:toggle_input_606694866()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_606694866;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_606694866 = document.getElementById("606694866");
#                 var cell = link_606694866;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_606694866;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_606694866 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_606694866 = cell.previousElementSibling;
#                 }
#                 input_606694866.style.display = "none"; // hide
#
#                 toggle_input_606694866 = function() {
#                     if (input_606694866.style.display == "none") {
#                         input_606694866.style.display = ""; // show
#                         link_606694866.innerHTML = "Hide Input";
#                     } else {
#                         input_606694866.style.display = "none"; // hide
#                         link_606694866.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_606694866 = $("a[id='606694866']");
#                 var cell_606694866 = link_606694866.parents("div.cell:first");
#                 if (cell_606694866.length == 0) {
#                     cell_606694866 = link_606694866.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_606694866 = cell_606694866.children("div.input");
#                 if (input_606694866.length == 0) {
#                     input_606694866 = cell_606694866.prev("div.nbinput");
#                 }
#                 input_606694866.hide();
#
#                 toggle_input_606694866 = function() {
#                     if (input_606694866.is(':hidden')) {
#                         input_606694866.slideDown();
#                         link_606694866[0].innerHTML = "Hide Input";
#                     } else {
#                         input_606694866.slideUp();
#                         link_606694866[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="2122896741" href="javascript:toggle_input_2122896741()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2122896741;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2122896741 = document.getElementById("2122896741");
#                 var cell = link_2122896741;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2122896741;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2122896741 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2122896741 = cell.previousElementSibling;
#                 }
#                 input_2122896741.style.display = "none"; // hide
#
#                 toggle_input_2122896741 = function() {
#                     if (input_2122896741.style.display == "none") {
#                         input_2122896741.style.display = ""; // show
#                         link_2122896741.innerHTML = "Hide Input";
#                     } else {
#                         input_2122896741.style.display = "none"; // hide
#                         link_2122896741.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2122896741 = $("a[id='2122896741']");
#                 var cell_2122896741 = link_2122896741.parents("div.cell:first");
#                 if (cell_2122896741.length == 0) {
#                     cell_2122896741 = link_2122896741.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2122896741 = cell_2122896741.children("div.input");
#                 if (input_2122896741.length == 0) {
#                     input_2122896741 = cell_2122896741.prev("div.nbinput");
#                 }
#                 input_2122896741.hide();
#
#                 toggle_input_2122896741 = function() {
#                     if (input_2122896741.is(':hidden')) {
#                         input_2122896741.slideDown();
#                         link_2122896741[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2122896741.slideUp();
#                         link_2122896741[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input, )
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(
    sim.trange(),
    sim.data[input_probe],
    label="Input signal")
plt.plot(
    sim.trange(),
    sim.data[Asquare_probe],
    label="Decoded esimate")
plt.plot(
    sim.trange(),
    np.square(sim.data[input_probe]),
    label="Input signal squared")
plt.legend(loc="best", fontsize='medium')
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="101714570" href="javascript:toggle_input_101714570()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_101714570;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_101714570 = document.getElementById("101714570");
#                 var cell = link_101714570;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_101714570;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_101714570 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_101714570 = cell.previousElementSibling;
#                 }
#                 input_101714570.style.display = "none"; // hide
#
#                 toggle_input_101714570 = function() {
#                     if (input_101714570.style.display == "none") {
#                         input_101714570.style.display = ""; // show
#                         link_101714570.innerHTML = "Hide Input";
#                     } else {
#                         input_101714570.style.display = "none"; // hide
#                         link_101714570.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_101714570 = $("a[id='101714570']");
#                 var cell_101714570 = link_101714570.parents("div.cell:first");
#                 if (cell_101714570.length == 0) {
#                     cell_101714570 = link_101714570.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_101714570 = cell_101714570.children("div.input");
#                 if (input_101714570.length == 0) {
#                     input_101714570 = cell_101714570.prev("div.nbinput");
#                 }
#                 input_101714570.hide();
#
#                 toggle_input_101714570 = function() {
#                     if (input_101714570.is(':hidden')) {
#                         input_101714570.slideDown();
#                         link_101714570[0].innerHTML = "Hide Input";
#                     } else {
#                         input_101714570.slideUp();
#                         link_101714570[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="774667891" href="javascript:toggle_input_774667891()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_774667891;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_774667891 = document.getElementById("774667891");
#                 var cell = link_774667891;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_774667891;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_774667891 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_774667891 = cell.previousElementSibling;
#                 }
#                 input_774667891.style.display = "none"; // hide
#
#                 toggle_input_774667891 = function() {
#                     if (input_774667891.style.display == "none") {
#                         input_774667891.style.display = ""; // show
#                         link_774667891.innerHTML = "Hide Input";
#                     } else {
#                         input_774667891.style.display = "none"; // hide
#                         link_774667891.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_774667891 = $("a[id='774667891']");
#                 var cell_774667891 = link_774667891.parents("div.cell:first");
#                 if (cell_774667891.length == 0) {
#                     cell_774667891 = link_774667891.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_774667891 = cell_774667891.children("div.input");
#                 if (input_774667891.length == 0) {
#                     input_774667891 = cell_774667891.prev("div.nbinput");
#                 }
#                 input_774667891.hide();
#
#                 toggle_input_774667891 = function() {
#                     if (input_774667891.is(':hidden')) {
#                         input_774667891.slideDown();
#                         link_774667891[0].innerHTML = "Hide Input";
#                     } else {
#                         input_774667891.slideUp();
#                         link_774667891[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="79478789" href="javascript:toggle_input_79478789()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_79478789;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_79478789 = document.getElementById("79478789");
#                 var cell = link_79478789;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_79478789;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_79478789 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_79478789 = cell.previousElementSibling;
#                 }
#                 input_79478789.style.display = "none"; // hide
#
#                 toggle_input_79478789 = function() {
#                     if (input_79478789.style.display == "none") {
#                         input_79478789.style.display = ""; // show
#                         link_79478789.innerHTML = "Hide Input";
#                     } else {
#                         input_79478789.style.display = "none"; // hide
#                         link_79478789.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_79478789 = $("a[id='79478789']");
#                 var cell_79478789 = link_79478789.parents("div.cell:first");
#                 if (cell_79478789.length == 0) {
#                     cell_79478789 = link_79478789.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_79478789 = cell_79478789.children("div.input");
#                 if (input_79478789.length == 0) {
#                     input_79478789 = cell_79478789.prev("div.nbinput");
#                 }
#                 input_79478789.hide();
#
#                 toggle_input_79478789 = function() {
#                     if (input_79478789.is(':hidden')) {
#                         input_79478789.slideDown();
#                         link_79478789[0].innerHTML = "Hide Input";
#                     } else {
#                         input_79478789.slideUp();
#                         link_79478789[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color='k')
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color='k')
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color='k')
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1567041149" href="javascript:toggle_input_1567041149()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1567041149;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1567041149 = document.getElementById("1567041149");
#                 var cell = link_1567041149;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1567041149;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1567041149 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1567041149 = cell.previousElementSibling;
#                 }
#                 input_1567041149.style.display = "none"; // hide
#
#                 toggle_input_1567041149 = function() {
#                     if (input_1567041149.style.display == "none") {
#                         input_1567041149.style.display = ""; // show
#                         link_1567041149.innerHTML = "Hide Input";
#                     } else {
#                         input_1567041149.style.display = "none"; // hide
#                         link_1567041149.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1567041149 = $("a[id='1567041149']");
#                 var cell_1567041149 = link_1567041149.parents("div.cell:first");
#                 if (cell_1567041149.length == 0) {
#                     cell_1567041149 = link_1567041149.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1567041149 = cell_1567041149.children("div.input");
#                 if (input_1567041149.length == 0) {
#                     input_1567041149 = cell_1567041149.prev("div.nbinput");
#                 }
#                 input_1567041149.hide();
#
#                 toggle_input_1567041149 = function() {
#                     if (input_1567041149.is(':hidden')) {
#                         input_1567041149.slideDown();
#                         link_1567041149[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1567041149.slideUp();
#                         link_1567041149[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(
        oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel('Time (s)')

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
hide_input()
# Out:
#         <a id="455801173" href="javascript:toggle_input_455801173()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_455801173;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_455801173 = document.getElementById("455801173");
#                 var cell = link_455801173;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_455801173;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_455801173 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_455801173 = cell.previousElementSibling;
#                 }
#                 input_455801173.style.display = "none"; // hide
#
#                 toggle_input_455801173 = function() {
#                     if (input_455801173.style.display == "none") {
#                         input_455801173.style.display = ""; // show
#                         link_455801173.innerHTML = "Hide Input";
#                     } else {
#                         input_455801173.style.display = "none"; // hide
#                         link_455801173.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_455801173 = $("a[id='455801173']");
#                 var cell_455801173 = link_455801173.parents("div.cell:first");
#                 if (cell_455801173.length == 0) {
#                     cell_455801173 = link_455801173.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_455801173 = cell_455801173.children("div.input");
#                 if (input_455801173.length == 0) {
#                     input_455801173 = cell_455801173.prev("div.nbinput");
#                 }
#                 input_455801173.hide();
#
#                 toggle_input_455801173 = function() {
#                     if (input_455801173.is(':hidden')) {
#                         input_455801173.slideDown();
#                         link_455801173[0].innerHTML = "Hide Input";
#                     } else {
#                         input_455801173.slideUp();
#                         link_455801173[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
