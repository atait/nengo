# %% [markdown]
# # Conventional solution to the Lorenz attractor using scipy

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import scipy as sp
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# the ODE to emulate
sigma = 6.5
beta = 8.0/3
rho = 28

def lorenz(x, t):
    dx0 = (-sigma * x[0] + sigma * x[1])
    dx1 = (-x[0] * x[2] - x[1])
    dx2 = (x[0] * x[1] - beta * (x[2] + rho))
    
    return np.array([dx0, 
                     dx1, 
                     dx2])

# Initial conditions of lorenz
init = np.array([0.1, 0.1, 0.1])
t = np.arange(0,200,0.01)
sol=odeint(lorenz, init, t)

fig = plt.figure(0, figsize=(10,8), dpi=72)
ax = fig.add_subplot(111, projection='3d')
dat3d = (sol[:, dim] for dim in range(3))
ax.plot(*dat3d, linewidth=0.5)
ax.set_xlabel('$x_0$ (a.u.)')
ax.set_ylabel('$x_1$ (a.u.)')
ax.set_zlabel('$x_2$ (a.u.)')
# for xlabel_i in ax.get_xticklabels():
#     xlabel_i.set_fontsize(5.0)
# for ylabel_i in ax.get_yticklabels():
#     ylabel_i.set_fontsize(5.0)
# for zlabel_i in ax.get_zticklabels():
#     zlabel_i.set_fontsize(5.0)

plt.tight_layout()
plt.show()
